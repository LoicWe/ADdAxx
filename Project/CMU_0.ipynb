# %% [markdown]
# # 1. Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from cdlib import viz
import os
import sys
import warnings
warnings.filterwarnings('ignore')
import pandas_profiling
import networkx as nx
from cdlib import algorithms, viz
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'graph_tool'}
# Note: to be able to use all bipartite methods, you need to install some additional packages:  {'wurlitzer'}

# %% [markdown]
# ## 1.1 Importing data

# %%
# load data from tsv file to a pandas dataframe
movies_metadata = pd.read_csv('movie.metadata.tsv', sep='\t', header=None)
character_metadata = pd.read_csv('character.metadata.tsv', sep='\t', header=None)
plot_summaries = pd.read_csv('plot_summaries.txt', sep='\t', header=None)

# %% [markdown]
# The columns have the following labels:
# <br> Movies metadata:
# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie name
# 4. Movie release date
# 5. Movie box office revenue
# 6. Movie runtime
# 7. Movie languages (Freebase ID:name tuples)
# 8. Movie countries (Freebase ID:name tuples)
# 9. Movie genres (Freebase ID:name tuples)
#
# Character/actors metadata:
# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie release date
# 4. Character name
# 5. Actor date of birth
# 6. Actor gender
# 7. Actor height (in meters)
# 8. Actor ethnicity (Freebase ID)
# 9. Actor name
# 10. Actor age at movie release
# 11. Freebase character/actor map ID
# 12. Freebase character ID
# 13. Freebase actor ID
#
# Plot summaries:
# 1. Wikipedia movie ID
# 2. Plot summary

# %%
#label the columns
movies_metadata.columns = ['Wikipedia_movie_ID', 'Freebase_movie_ID', 'Movie_name', 'Movie_release_date', 'Movie_box_office_revenue', 'Movie_runtime', 'Movie_languages', 'Movie_countries', 'Movie_genres'] 
character_metadata.columns = ['Wikipedia_movie_ID', 'Freebase_movie_ID', 'Movie_release_date', 'Character_name', 'Actor_date_of_birth', 'actor_gender', 'Actor_height_(in_meters)', 'Actor_ethnicity', 'Actor_name', 'Actor_age_at_movie_release', 'Freebase_character/actor_map_ID', 'Freebase_character_ID', 'Freebase_actor_ID']
plot_summaries.columns = ['Wikipedia_movie_ID', 'Plot_summary']

# %% [markdown]
# ## 1.2 Visualizing row data

# %%
movies_metadata.sample(3)
# Out:
#        Wikipedia_movie_ID Freebase_movie_ID              Movie_name  \
# 44686             5656505         /m/0dyl93           The Cameraman
# 46240            31580170        /m/0glrcp_           Make It Three
# 19169            19092476        /m/04jk1y6  One or the Other of Us
#
#       Movie_release_date  Movie_box_office_revenue  Movie_runtime  \
# 44686               1928                       NaN           69.0
# 46240               1938                       NaN            NaN
# 19169                NaN                       NaN          105.0
#
#                                          Movie_languages  \
# 44686  {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# 46240                 {"/m/02h40lc": "English Language"}
# 19169                  {"/m/04306rv": "German Language"}
#
#                                  Movie_countries  \
# 44686  {"/m/09c7w0": "United States of America"}
# 46240             {"/m/07ssc": "United Kingdom"}
# 19169               {"/m/082fr": "West Germany"}
#
#                                             Movie_genres
# 44686  {"/m/06cvj": "Romantic comedy", "/m/06ppq": "S...
# 46240                       {"/m/05p553": "Comedy film"}
# 19169            {"/m/09blyk": "Psychological thriller"}

# %%
character_metadata.sample(3)
# Out:
#         Wikipedia_movie_ID Freebase_movie_ID Movie_release_date  \
# 347748            28478708        /m/0crfxnj         1958-12-26
# 234782             6361585         /m/0g2h97         2008-03-31
# 162960            28554140        /m/0cz92by            1934-11
#
#                 Character_name Actor_date_of_birth actor_gender  \
# 347748                     NaN          1914-06-24            F
# 234782  Manfred von Richthofen          1981-03-11            M
# 162960                     NaN          1893-07-18            F
#
#         Actor_height_(in_meters) Actor_ethnicity             Actor_name  \
# 347748                       NaN             NaN            Kari Diesen
# 234782                       1.8             NaN  Matthias Schweighöfer
# 162960                       NaN             NaN         Phyllis Morris
#
#         Actor_age_at_movie_release Freebase_character/actor_map_ID  \
# 347748                        44.0                      /m/0g98x2w
# 234782                        27.0                       /m/0k686_
# 162960                         NaN                      /m/0gglq22
#
#        Freebase_character_ID Freebase_actor_ID
# 347748                   NaN        /m/0bmd84y
# 234782            /m/0h5t79g         /m/0fw8ty
# 162960                   NaN        /m/0cv7jv_

# %%
plot_summaries.sample(3)
# Out:
#        Wikipedia_movie_ID                                       Plot_summary
# 3083             11691107   The story revolves around Michael "Little Man...
# 34986            33427517  Dil  is getting engaged to Abhay Thakur agains...
# 28080            10135050  Malee is a farm girl from Northern Thailand wh...

# %% [markdown]
# # 2. Understanding and cleaning data

# %% [markdown]
# ## 2.1 Exploring raw data

# %% [markdown]
# We use the pandas_profiling librarie to get a first rapid overview of the data. It gives many information like value repartition, correlations and missing values.
# <br>It ouptput the `character_metadata_report.html` and `movies_metadata_report.html` which can be found in the repo and doesn't requierd to re-run every time so we comment it.

# %%
# # profile the movies metadata dataframe
# movies_metadata.profile_report(title='Movies Metadata Report')
# # show the profile report
# movies_metadata.profile_report()

# %%
# # profile the character metadata dataframe
# character_metadata.profile_report(title='Character Metadata Report')
# # show the profile report
# character_metadata.profile_report()

# %% [markdown]
# We remark that for movies the `Movie_box_office_revenue`, `Movie_runtime` columns have some missing values and we face the same problems with those columns `Character_name`, `Actor_date_of_birth`, `Actor_height_(in_meters)`, `Actor_ethnicity` in the actor dataset. We'll probably not use most of them except for the boxoffice revenue and the ethnicity who could be interresting but will need some scarping to add missing values.

# %% [markdown]
# ## 2.2 Cleaning the data

# %% [markdown]
# We aim to create a network between actors as nodes and movies as edges. Therfor we need to match those two different dataframes. The `Wikipedia_movie_ID` and `Freebase_movie_ID` are perfect for that as they have no missing values. Furthermore we choose to use `Actor_name` as identifier for the actors as it didn't have any missing values.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>
#         !!! could be interresting to analyse more `actor_name` see if we have names with typo or sommething like that
#     </b>
# </div>

# %%
from difflib import SequenceMatcher , get_close_matches

# %%
s1 = "abcdefg"
list_one = ["abcdefghi" , "abcdef" , "htyudjh" , "abcxyzg"]
match = get_close_matches(s1, list_one, cutoff=0.6)
print(match)
# Out:
# ['abcdef', 'abcdefghi']

# %%
# create a dataframe referencing every actor_names
actors_unique = character_metadata.drop_duplicates('Actor_name')
actors_unique = actors_unique.dropna(subset=['Actor_name'])

birth_unique = character_metadata.drop_duplicates('Actor_date_of_birth')

# check if every same actor_names refer to same actor_id
for b in birth_unique.Actor_date_of_birth:
    same_birth = character_metadata.query("`Actor_date_of_birth` == @b")
    if same_birth.Actor_name.nunique() > 1 & same_birth.actor_gender.nunique() > 1:
        actor_id_unique = same_birth.drop_duplicates('Freebase_actor_ID')
        for i in actor_id_unique.Freebase_actor_ID:
            same_name = same_birth.query("`Freebase_actor_ID` == @i")
            if same_name.Actor_name.nunique() > 1:
                print("Freebase id: ", i, " | names: ", same_name.unique())
    
    
    
    
    
    # same_name = character_metadata.query("`Actor_name` == @a")
    # if same_name.Freebase_actor_ID.nunique() > 1 & same_name.Actor_date_of_birth.nunique() > 1 & same_name.actor_gender.nunique() > 1:
    #     print(a, same_name.Freebase_actor_ID.unique())
# character_metadata.query("`Actor_name` == @t").Freebase_actor_ID.nunique()   #actors_unique.Actor_name.iloc[0]

# %%
# create a dataframe referencing every actor_names
actors_unique = character_metadata.drop_duplicates('Actor_name')
actors_unique = actors_unique.dropna(subset=['Actor_name'])

birth_unique = character_metadata.drop_duplicates('Actor_date_of_birth')

actor_id_unique = character_metadata.drop_duplicates('Freebase_actor_ID')
for i in actor_id_unique.Freebase_actor_ID:
    same_name = same_birth.query("`Freebase_actor_ID` == @i")
    if same_name.Actor_name.nunique() > 1:
        print("Freebase id: ", i, " | names: ", same_name.unique())

# %%
# for n in actors1.Actor_name:
#     if type(n) == t:
#         match = get_close_matches(n,actors1.Actor_name , cutoff=0.9)
#         if len(match) > 1:
#             print(match)

# %%
# filter characters metadata dataframe to keep only the characters where the character name and actor name are not null
characters_before_filter = character_metadata.shape[0]
character_metadata = character_metadata[character_metadata['Freebase_actor_ID'].notnull()]
# show how many characters were originally in the dataframe, how many were removed and how many are left
print('Number of characters before filter: ', characters_before_filter)
print('Number of characters after filter: ', character_metadata.shape[0])
print('Number of characters removed: ', characters_before_filter - character_metadata.shape[0])
# Out:
# Number of characters before filter:  450669
# Number of characters after filter:  449854
# Number of characters removed:  815

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>
#         Check utility of filtering actors
#         <br>for movies: normal to have > and not >= ?
#     </b>
# </div>

# %% [markdown]
# We need movies that have at least 2 actors to connect the nodes.

# %%
# list the characters of each movie in a list and the actors of each movie in a list
actors = character_metadata.groupby('Wikipedia_movie_ID')['Actor_name'].apply(list).reset_index().rename(columns={'Actor_name': 'Actors_names'})
# count the actors of each movie
actors['Number_of_actors'] = actors['Actors_names'].apply(lambda x: len(x))
# filter the actors dataframe to keep only the movies with more than 2 actors
actors = actors[actors['Number_of_actors'] > 2].reset_index(drop=True)
# show the number of movies before and after the filter and how many movies were removed
print('Number of movies before filter: ', character_metadata['Wikipedia_movie_ID'].nunique())
print('Number of movies after filter: ', actors.shape[0])
print('Number of movies removed: ', character_metadata['Wikipedia_movie_ID'].nunique() - actors.shape[0])
# Out:
# Number of movies before filter:  64308
# Number of movies after filter:  48816
# Number of movies removed:  15492

# %% [markdown]
# ## 2.2 Further exploration of cleaned data

# %% [markdown]
# Now that we have drop the data that won't be usefull we can start analysing it.

# %%
# Firstly print the new dataframe merging movies and actors
actors
# Out:
#        Wikipedia_movie_ID                                       Actors_names  \
# 0                     330  [Rosa Maria Sardà, Mercè Pons, Anna Lizaran, N...
# 1                    3217  [Ted Raimi, Ivan Raimi, Bruce Campbell, Bruce ...
# 2                    3333  [Lillian Gish, Henry B. Walthall, Mae Marsh, S...
# 3                    3746  [William Sanderson, Harrison Ford, Rutger Haue...
# 4                    3837  [Jack Starrett, Slim Pickens, Dave Sharpe, Lia...
# ...                   ...                                                ...
# 48811            37322106      [Katrina Kaif, Shahrukh Khan, Anushka Sharma]
# 48812            37373877  [Gabrielle Anwar, Traci Lords, Dina Meyer, Geo...
# 48813            37476824  [Zayed Khan, Raveena Tandon, Amitabh Bachchan,...
# 48814            37478048  [Anupam Kher, Anil Kapoor, Sridevi Kapoor, Akk...
# 48815            37492363  [Molly Cera, Taylor Marie Milton, Spencer Jenk...
#
#        Number_of_actors
# 0                     4
# 1                    14
# 2                    14
# 3                    15
# 4                    20
# ...                 ...
# 48811                 3
# 48812                 7
# 48813                10
# 48814                 4
# 48815                 3
#
# [48816 rows x 3 columns]

# %%
plot = sns.displot(actors['Wikipedia_movie_ID'], x = actors['Number_of_actors'],
                   log=True, discrete=True, aspect = 3)
plot = plot.set(title = 'Distribution of the number of actors per movie', 
               xlabel = 'Number of actors',
               ylabel = 'Number of movies')

# %% [markdown]
# # 3. Creating a network of actors

# %% [markdown]
# It's now time to creat a first network

# %% [markdown]
# ## 3.1 Processing the data

# %%
# one actor per line in the new dataframe
actors_new_meta = actors.merge(character_metadata[['Character_name', 'Actor_name', 'Wikipedia_movie_ID']], on='Wikipedia_movie_ID', how='inner')

# %%
actors_new_meta.sample(3)
# Out:
#         Wikipedia_movie_ID                                       Actors_names  \
# 368639            27543848  [Chantal Banlier, Isabelle Huppert, Lolita Cha...
# 400192            31357325  [David Rhein, Marlene Rhein, Robert Costanzo, ...
# 418440            33952827  [Shin-yeong Jang, Guo Yong-zhen, Qian Liu, Wan...
#
#         Number_of_actors Character_name        Actor_name
# 368639                 6            NaN  Isabelle Huppert
# 400192                10            NaN       David Rhein
# 418440                 8            NaN          Qian Liu

# %%
# dataframe with pairs of actors and the number of movies they acted in together
# the dataframe to merge contains all the actors_new_meta dataframe except the actors_names column
to_merge = actors_new_meta.drop('Actors_names', axis=1)
actors_pairs = to_merge.merge(to_merge, on=['Wikipedia_movie_ID', 'Number_of_actors'], how='inner')
# filter the dataframe to keep only the pairs where the actor names are different
actors_pairs = actors_pairs[actors_pairs['Actor_name_x'] != actors_pairs['Actor_name_y']]
# filter the dataframe to keep only the pairs that are not interchangeable (actor1, actor2) and (actor2, actor1)
actors_pairs = actors_pairs[actors_pairs['Actor_name_x'] < actors_pairs['Actor_name_y']]

# %%
# for each pair make a new column with the list of movies they acted in together
actors_pairs_common_movies = actors_pairs.groupby(['Actor_name_x', 'Actor_name_y'])['Wikipedia_movie_ID'].apply(list).reset_index().rename(columns={'Wikipedia_movie_ID': 'Common_movies'})
# remove the duplicates in the movies list
actors_pairs_common_movies['Common_movies'] = actors_pairs_common_movies['Common_movies'].apply(lambda x: list(set(x)))

# %%
# number of common movies between each pair of actors
actors_pairs_common_movies['Number_of_common_movies'] = actors_pairs_common_movies['Common_movies'].apply(lambda x: len(x))

# %%
# filter the dataframe to keep only the pairs that acted in more than 2 movies together
actors_pairs_common_movies_filtered = actors_pairs_common_movies[actors_pairs_common_movies['Number_of_common_movies'] > 2]

# %%
actors_pairs_common_movies_filtered.sample(3)
# Out:
#             Actor_name_x    Actor_name_y  \
# 827511   Dharmendra Deol  Dimple Kapadia
# 637543     Chunky Pandey     Kiran Kumar
# 1022014    Finlay Currie   Robert Morley
#
#                                              Common_movies  \
# 827511   [10640931, 33406468, 33002698, 33002477, 31196...
# 637543                        [29381473, 33332910, 574342]
# 1022014                       [1133816, 26084706, 3705395]
#
#          Number_of_common_movies
# 827511                         8
# 637543                         3
# 1022014                        3

# %% [markdown]
# ## 3.2 Creating the network

# %% [markdown]
# There are many ways to create networks, a really common one is the networkx library. It offers lots of tools and we can easily find documentation on the web.

# %%
# create a non directed graph from the dataframe
G = nx.from_pandas_edgelist(actors_pairs_common_movies_filtered, source='Actor_name_x', target='Actor_name_y', edge_attr='Number_of_common_movies')
# show the number of nodes and edges in the graph
print('Number of nodes: ', G.number_of_nodes())
print('Number of edges: ', G.number_of_edges())
# Out:
# Number of nodes:  8418
# Number of edges:  25900

# %% [markdown]
# Now that we have the network we'll need to analyse it. The first step is to create subgroup using the louvain algorithm.

# %%
# make partitions of the graph 
coms = algorithms.louvain(G, weight='Number_of_common_movies')

# make subgraphs from the partitions
subgraphs = [G.subgraph(c) for c in coms.communities]
# show the number of subgraphs
print('Number of communities: ', len(subgraphs))
# Out:
# Number of communities:  640

# %%
# show the number of nodes in each subgraph and the average weight of the edges in each subgraph
for i, subgraph in enumerate(subgraphs):
    print('community ', i + 1, ' number of actors: ', subgraph.number_of_nodes())
    print('community ', i + 1, ' average numbers of movies between actors: ', subgraph.size(weight='Number_of_common_movies') / subgraph.number_of_edges())
# Out:
# community  1  number of actors:  995
# community  1  average numbers of movies between actors:  3.668041237113402
# community  2  number of actors:  886
# community  2  average numbers of movies between actors:  3.513723150357995
# community  3  number of actors:  719
# community  3  average numbers of movies between actors:  4.475798737325426
# community  4  number of actors:  555
# community  4  average numbers of movies between actors:  3.7219167321288293
# community  5  number of actors:  464
# community  5  average numbers of movies between actors:  3.6295603367633302
# community  6  number of actors:  432
# community  6  average numbers of movies between actors:  4.997916666666667
# community  7  number of actors:  330
# community  7  average numbers of movies between actors:  4.612226277372263
# community  8  number of actors:  274
# community  8  average numbers of movies between actors:  3.9496296296296296
# community  9  number of actors:  215
# community  9  average numbers of movies between actors:  4.064263322884012
# community  10  number of actors:  173
# community  10  average numbers of movies between actors:  5.62749445676275
# community  11  number of actors:  166
# community  11  average numbers of movies between actors:  3.6387832699619773
# community  12  number of actors:  166
# community  12  average numbers of movies between actors:  4.850383631713555
# community  13  number of actors:  151
# community  13  average numbers of movies between actors:  5.8731884057971016
# community  14  number of actors:  124
# community  14  average numbers of movies between actors:  3.8065693430656933
# community  15  number of actors:  119
# community  15  average numbers of movies between actors:  4.405594405594406
# community  16  number of actors:  115
# community  16  average numbers of movies between actors:  3.828326180257511
# community  17  number of actors:  82
# community  17  average numbers of movies between actors:  9.141486810551559
# community  18  number of actors:  66
# community  18  average numbers of movies between actors:  3.5107913669064748
# community  19  number of actors:  58
# community  19  average numbers of movies between actors:  7.713483146067416
# community  20  number of actors:  58
# community  20  average numbers of movies between actors:  3.7194244604316546
# community  21  number of actors:  52
# community  21  average numbers of movies between actors:  4.867403314917127
# community  22  number of actors:  51
# community  22  average numbers of movies between actors:  3.40625
# community  23  number of actors:  49
# community  23  average numbers of movies between actors:  3.473684210526316
# community  24  number of actors:  48
# community  24  average numbers of movies between actors:  3.357142857142857
# community  25  number of actors:  45
# community  25  average numbers of movies between actors:  4.329411764705882
# community  26  number of actors:  35
# community  26  average numbers of movies between actors:  3.4150943396226414
# community  27  number of actors:  24
# community  27  average numbers of movies between actors:  3.230769230769231
# community  28  number of actors:  22
# community  28  average numbers of movies between actors:  4.3023255813953485
# community  29  number of actors:  21
# community  29  average numbers of movies between actors:  3.6411764705882352
# community  30  number of actors:  20
# community  30  average numbers of movies between actors:  4.885714285714286
# community  31  number of actors:  19
# community  31  average numbers of movies between actors:  3.111111111111111
# community  32  number of actors:  18
# community  32  average numbers of movies between actors:  6.7924528301886795
# community  33  number of actors:  18
# community  33  average numbers of movies between actors:  4.2105263157894735
# community  34  number of actors:  18
# community  34  average numbers of movies between actors:  3.4375
# community  35  number of actors:  17
# community  35  average numbers of movies between actors:  3.1
# community  36  number of actors:  16
# community  36  average numbers of movies between actors:  3.2941176470588234
# community  37  number of actors:  15
# community  37  average numbers of movies between actors:  3.375
# community  38  number of actors:  13
# community  38  average numbers of movies between actors:  3.4166666666666665
# community  39  number of actors:  12
# community  39  average numbers of movies between actors:  3.4545454545454546
# community  40  number of actors:  12
# community  40  average numbers of movies between actors:  3.3846153846153846
# community  41  number of actors:  12
# community  41  average numbers of movies between actors:  3.6875
# community  42  number of actors:  11
# community  42  average numbers of movies between actors:  3.1818181818181817
# community  43  number of actors:  11
# community  43  average numbers of movies between actors:  4.375
# community  44  number of actors:  11
# community  44  average numbers of movies between actors:  3.0217391304347827
# community  45  number of actors:  11
# community  45  average numbers of movies between actors:  3.230769230769231
# community  46  number of actors:  11
# community  46  average numbers of movies between actors:  3.642857142857143
# community  47  number of actors:  11
# community  47  average numbers of movies between actors:  3.3
# community  48  number of actors:  11
# community  48  average numbers of movies between actors:  3.611111111111111
# community  49  number of actors:  11
# community  49  average numbers of movies between actors:  4.3076923076923075
# community  50  number of actors:  10
# community  50  average numbers of movies between actors:  3.466666666666667
# community  51  number of actors:  10
# community  51  average numbers of movies between actors:  3.5789473684210527
# community  52  number of actors:  9
# community  52  average numbers of movies between actors:  3.3333333333333335
# community  53  number of actors:  9
# community  53  average numbers of movies between actors:  3.3333333333333335
# community  54  number of actors:  9
# community  54  average numbers of movies between actors:  3.1818181818181817
# community  55  number of actors:  9
# community  55  average numbers of movies between actors:  3.7
# community  56  number of actors:  9
# community  56  average numbers of movies between actors:  3.269230769230769
# community  57  number of actors:  9
# community  57  average numbers of movies between actors:  3.090909090909091
# community  58  number of actors:  9
# community  58  average numbers of movies between actors:  3.5
# community  59  number of actors:  8
# community  59  average numbers of movies between actors:  3.142857142857143
# community  60  number of actors:  8
# community  60  average numbers of movies between actors:  3.411764705882353
# community  61  number of actors:  8
# community  61  average numbers of movies between actors:  5.818181818181818
# community  62  number of actors:  8
# community  62  average numbers of movies between actors:  5.913043478260869
# community  63  number of actors:  8
# community  63  average numbers of movies between actors:  4.214285714285714
# community  64  number of actors:  8
# community  64  average numbers of movies between actors:  3.0434782608695654
# community  65  number of actors:  7
# community  65  average numbers of movies between actors:  3.727272727272727
# community  66  number of actors:  7
# community  66  average numbers of movies between actors:  3.6
# community  67  number of actors:  7
# community  67  average numbers of movies between actors:  3.1666666666666665
# community  68  number of actors:  7
# community  68  average numbers of movies between actors:  3.0
# community  69  number of actors:  7
# community  69  average numbers of movies between actors:  3.3333333333333335
# community  70  number of actors:  7
# community  70  average numbers of movies between actors:  7.523809523809524
# community  71  number of actors:  7
# community  71  average numbers of movies between actors:  3.0476190476190474
# community  72  number of actors:  7
# community  72  average numbers of movies between actors:  3.857142857142857
# community  73  number of actors:  7
# community  73  average numbers of movies between actors:  3.5
# community  74  number of actors:  7
# community  74  average numbers of movies between actors:  3.0
# community  75  number of actors:  6
# community  75  average numbers of movies between actors:  3.1666666666666665
# community  76  number of actors:  6
# community  76  average numbers of movies between actors:  3.5
# community  77  number of actors:  6
# community  77  average numbers of movies between actors:  3.4285714285714284
# community  78  number of actors:  6
# community  78  average numbers of movies between actors:  3.066666666666667
# community  79  number of actors:  6
# community  79  average numbers of movies between actors:  3.0
# community  80  number of actors:  6
# community  80  average numbers of movies between actors:  3.0
# community  81  number of actors:  6
# community  81  average numbers of movies between actors:  3.375
# community  82  number of actors:  6
# community  82  average numbers of movies between actors:  3.6666666666666665
# community  83  number of actors:  6
# community  83  average numbers of movies between actors:  4.8
# community  84  number of actors:  6
# community  84  average numbers of movies between actors:  3.4
# community  85  number of actors:  6
# community  85  average numbers of movies between actors:  3.75
# community  86  number of actors:  6
# community  86  average numbers of movies between actors:  3.6666666666666665
# community  87  number of actors:  6
# community  87  average numbers of movies between actors:  3.3333333333333335
# community  88  number of actors:  6
# community  88  average numbers of movies between actors:  3.0
# community  89  number of actors:  6
# community  89  average numbers of movies between actors:  3.6666666666666665
# community  90  number of actors:  6
# community  90  average numbers of movies between actors:  3.4
# community  91  number of actors:  6
# community  91  average numbers of movies between actors:  3.142857142857143
# community  92  number of actors:  6
# community  92  average numbers of movies between actors:  3.0
# community  93  number of actors:  6
# community  93  average numbers of movies between actors:  5.375
# community  94  number of actors:  5
# community  94  average numbers of movies between actors:  3.5714285714285716
# community  95  number of actors:  5
# community  95  average numbers of movies between actors:  3.0
# community  96  number of actors:  5
# community  96  average numbers of movies between actors:  3.0
# community  97  number of actors:  5
# community  97  average numbers of movies between actors:  3.6666666666666665
# community  98  number of actors:  5
# community  98  average numbers of movies between actors:  3.4
# community  99  number of actors:  5
# community  99  average numbers of movies between actors:  3.4285714285714284
# community  100  number of actors:  5
# community  100  average numbers of movies between actors:  3.1
# community  101  number of actors:  5
# community  101  average numbers of movies between actors:  3.875
# community  102  number of actors:  5
# community  102  average numbers of movies between actors:  3.4285714285714284
# community  103  number of actors:  5
# community  103  average numbers of movies between actors:  3.25
# community  104  number of actors:  5
# community  104  average numbers of movies between actors:  3.0
# community  105  number of actors:  5
# community  105  average numbers of movies between actors:  3.0
# community  106  number of actors:  5
# community  106  average numbers of movies between actors:  3.0
# community  107  number of actors:  5
# community  107  average numbers of movies between actors:  9.0
# community  108  number of actors:  5
# community  108  average numbers of movies between actors:  3.25
# community  109  number of actors:  5
# community  109  average numbers of movies between actors:  3.0
# community  110  number of actors:  5
# community  110  average numbers of movies between actors:  5.8
# community  111  number of actors:  5
# community  111  average numbers of movies between actors:  3.0
# community  112  number of actors:  5
# community  112  average numbers of movies between actors:  3.142857142857143
# community  113  number of actors:  4
# community  113  average numbers of movies between actors:  3.6
# community  114  number of actors:  4
# community  114  average numbers of movies between actors:  8.0
# community  115  number of actors:  4
# community  115  average numbers of movies between actors:  3.0
# community  116  number of actors:  4
# community  116  average numbers of movies between actors:  3.0
# community  117  number of actors:  4
# community  117  average numbers of movies between actors:  4.5
# community  118  number of actors:  4
# community  118  average numbers of movies between actors:  3.25
# community  119  number of actors:  4
# community  119  average numbers of movies between actors:  3.0
# community  120  number of actors:  4
# community  120  average numbers of movies between actors:  3.0
# community  121  number of actors:  4
# community  121  average numbers of movies between actors:  3.0
# community  122  number of actors:  4
# community  122  average numbers of movies between actors:  3.0
# community  123  number of actors:  4
# community  123  average numbers of movies between actors:  3.6666666666666665
# community  124  number of actors:  4
# community  124  average numbers of movies between actors:  13.0
# community  125  number of actors:  4
# community  125  average numbers of movies between actors:  3.0
# community  126  number of actors:  4
# community  126  average numbers of movies between actors:  4.0
# community  127  number of actors:  4
# community  127  average numbers of movies between actors:  4.0
# community  128  number of actors:  4
# community  128  average numbers of movies between actors:  5.333333333333333
# community  129  number of actors:  4
# community  129  average numbers of movies between actors:  3.0
# community  130  number of actors:  4
# community  130  average numbers of movies between actors:  3.0
# community  131  number of actors:  4
# community  131  average numbers of movies between actors:  5.166666666666667
# community  132  number of actors:  4
# community  132  average numbers of movies between actors:  3.0
# community  133  number of actors:  4
# community  133  average numbers of movies between actors:  3.0
# community  134  number of actors:  4
# community  134  average numbers of movies between actors:  3.1666666666666665
# community  135  number of actors:  4
# community  135  average numbers of movies between actors:  4.0
# community  136  number of actors:  4
# community  136  average numbers of movies between actors:  3.0
# community  137  number of actors:  4
# community  137  average numbers of movies between actors:  3.6
# community  138  number of actors:  4
# community  138  average numbers of movies between actors:  3.0
# community  139  number of actors:  4
# community  139  average numbers of movies between actors:  3.3333333333333335
# community  140  number of actors:  4
# community  140  average numbers of movies between actors:  3.1666666666666665
# community  141  number of actors:  4
# community  141  average numbers of movies between actors:  3.3333333333333335
# community  142  number of actors:  4
# community  142  average numbers of movies between actors:  3.3333333333333335
# community  143  number of actors:  4
# community  143  average numbers of movies between actors:  3.0
# community  144  number of actors:  4
# community  144  average numbers of movies between actors:  3.4
# community  145  number of actors:  4
# community  145  average numbers of movies between actors:  3.2
# community  146  number of actors:  4
# community  146  average numbers of movies between actors:  3.8333333333333335
# community  147  number of actors:  4
# community  147  average numbers of movies between actors:  3.1666666666666665
# community  148  number of actors:  4
# community  148  average numbers of movies between actors:  3.0
# community  149  number of actors:  4
# community  149  average numbers of movies between actors:  3.25
# community  150  number of actors:  4
# community  150  average numbers of movies between actors:  3.25
# community  151  number of actors:  4
# community  151  average numbers of movies between actors:  3.5
# community  152  number of actors:  4
# community  152  average numbers of movies between actors:  3.0
# community  153  number of actors:  3
# community  153  average numbers of movies between actors:  4.333333333333333
# community  154  number of actors:  3
# community  154  average numbers of movies between actors:  3.0
# community  155  number of actors:  3
# community  155  average numbers of movies between actors:  3.0
# community  156  number of actors:  3
# community  156  average numbers of movies between actors:  3.0
# community  157  number of actors:  3
# community  157  average numbers of movies between actors:  3.0
# community  158  number of actors:  3
# community  158  average numbers of movies between actors:  3.0
# community  159  number of actors:  3
# community  159  average numbers of movies between actors:  3.0
# community  160  number of actors:  3
# community  160  average numbers of movies between actors:  3.5
# community  161  number of actors:  3
# community  161  average numbers of movies between actors:  4.0
# community  162  number of actors:  3
# community  162  average numbers of movies between actors:  3.5
# community  163  number of actors:  3
# community  163  average numbers of movies between actors:  3.5
# community  164  number of actors:  3
# community  164  average numbers of movies between actors:  3.0
# community  165  number of actors:  3
# community  165  average numbers of movies between actors:  3.6666666666666665
# community  166  number of actors:  3
# community  166  average numbers of movies between actors:  3.0
# community  167  number of actors:  3
# community  167  average numbers of movies between actors:  3.0
# community  168  number of actors:  3
# community  168  average numbers of movies between actors:  3.0
# community  169  number of actors:  3
# community  169  average numbers of movies between actors:  3.0
# community  170  number of actors:  3
# community  170  average numbers of movies between actors:  3.0
# community  171  number of actors:  3
# community  171  average numbers of movies between actors:  3.0
# community  172  number of actors:  3
# community  172  average numbers of movies between actors:  3.0
# community  173  number of actors:  3
# community  173  average numbers of movies between actors:  3.0
# community  174  number of actors:  3
# community  174  average numbers of movies between actors:  3.0
# community  175  number of actors:  3
# community  175  average numbers of movies between actors:  4.0
# community  176  number of actors:  3
# community  176  average numbers of movies between actors:  7.333333333333333
# community  177  number of actors:  3
# community  177  average numbers of movies between actors:  3.0
# community  178  number of actors:  3
# community  178  average numbers of movies between actors:  3.5
# community  179  number of actors:  3
# community  179  average numbers of movies between actors:  3.0
# community  180  number of actors:  3
# community  180  average numbers of movies between actors:  4.5
# community  181  number of actors:  3
# community  181  average numbers of movies between actors:  3.0
# community  182  number of actors:  3
# community  182  average numbers of movies between actors:  4.0
# community  183  number of actors:  3
# community  183  average numbers of movies between actors:  3.5
# community  184  number of actors:  3
# community  184  average numbers of movies between actors:  3.3333333333333335
# community  185  number of actors:  3
# community  185  average numbers of movies between actors:  3.6666666666666665
# community  186  number of actors:  3
# community  186  average numbers of movies between actors:  4.333333333333333
# community  187  number of actors:  3
# community  187  average numbers of movies between actors:  3.0
# community  188  number of actors:  3
# community  188  average numbers of movies between actors:  3.0
# community  189  number of actors:  3
# community  189  average numbers of movies between actors:  3.0
# community  190  number of actors:  3
# community  190  average numbers of movies between actors:  6.0
# community  191  number of actors:  3
# community  191  average numbers of movies between actors:  3.0
# community  192  number of actors:  3
# community  192  average numbers of movies between actors:  3.3333333333333335
# community  193  number of actors:  3
# community  193  average numbers of movies between actors:  3.0
# community  194  number of actors:  3
# community  194  average numbers of movies between actors:  3.0
# community  195  number of actors:  3
# community  195  average numbers of movies between actors:  3.0
# community  196  number of actors:  3
# community  196  average numbers of movies between actors:  3.0
# community  197  number of actors:  3
# community  197  average numbers of movies between actors:  3.0
# community  198  number of actors:  3
# community  198  average numbers of movies between actors:  3.0
# community  199  number of actors:  3
# community  199  average numbers of movies between actors:  3.0
# community  200  number of actors:  3
# community  200  average numbers of movies between actors:  3.0
# community  201  number of actors:  3
# community  201  average numbers of movies between actors:  3.0
# community  202  number of actors:  3
# community  202  average numbers of movies between actors:  3.0
# community  203  number of actors:  3
# community  203  average numbers of movies between actors:  3.5
# community  204  number of actors:  3
# community  204  average numbers of movies between actors:  3.0
# community  205  number of actors:  3
# community  205  average numbers of movies between actors:  3.0
# community  206  number of actors:  3
# community  206  average numbers of movies between actors:  3.3333333333333335
# community  207  number of actors:  3
# community  207  average numbers of movies between actors:  3.0
# community  208  number of actors:  3
# community  208  average numbers of movies between actors:  3.0
# community  209  number of actors:  3
# community  209  average numbers of movies between actors:  3.0
# community  210  number of actors:  3
# community  210  average numbers of movies between actors:  3.0
# community  211  number of actors:  3
# community  211  average numbers of movies between actors:  3.0
# community  212  number of actors:  3
# community  212  average numbers of movies between actors:  3.0
# community  213  number of actors:  3
# community  213  average numbers of movies between actors:  3.0
# community  214  number of actors:  3
# community  214  average numbers of movies between actors:  3.3333333333333335
# community  215  number of actors:  3
# community  215  average numbers of movies between actors:  3.0
# community  216  number of actors:  3
# community  216  average numbers of movies between actors:  3.0
# community  217  number of actors:  3
# community  217  average numbers of movies between actors:  3.0
# community  218  number of actors:  3
# community  218  average numbers of movies between actors:  3.0
# community  219  number of actors:  3
# community  219  average numbers of movies between actors:  3.5
# community  220  number of actors:  3
# community  220  average numbers of movies between actors:  3.0
# community  221  number of actors:  3
# community  221  average numbers of movies between actors:  3.0
# community  222  number of actors:  3
# community  222  average numbers of movies between actors:  3.5
# community  223  number of actors:  3
# community  223  average numbers of movies between actors:  4.0
# community  224  number of actors:  3
# community  224  average numbers of movies between actors:  5.5
# community  225  number of actors:  3
# community  225  average numbers of movies between actors:  3.0
# community  226  number of actors:  3
# community  226  average numbers of movies between actors:  4.333333333333333
# community  227  number of actors:  3
# community  227  average numbers of movies between actors:  3.0
# community  228  number of actors:  3
# community  228  average numbers of movies between actors:  3.0
# community  229  number of actors:  3
# community  229  average numbers of movies between actors:  3.0
# community  230  number of actors:  3
# community  230  average numbers of movies between actors:  3.5
# community  231  number of actors:  3
# community  231  average numbers of movies between actors:  3.0
# community  232  number of actors:  3
# community  232  average numbers of movies between actors:  3.0
# community  233  number of actors:  3
# community  233  average numbers of movies between actors:  4.0
# community  234  number of actors:  3
# community  234  average numbers of movies between actors:  3.0
# community  235  number of actors:  3
# community  235  average numbers of movies between actors:  3.3333333333333335
# community  236  number of actors:  3
# community  236  average numbers of movies between actors:  4.0
# community  237  number of actors:  3
# community  237  average numbers of movies between actors:  3.0
# community  238  number of actors:  3
# community  238  average numbers of movies between actors:  3.3333333333333335
# community  239  number of actors:  3
# community  239  average numbers of movies between actors:  3.0
# community  240  number of actors:  3
# community  240  average numbers of movies between actors:  3.0
# community  241  number of actors:  3
# community  241  average numbers of movies between actors:  4.333333333333333
# community  242  number of actors:  3
# community  242  average numbers of movies between actors:  3.5
# community  243  number of actors:  3
# community  243  average numbers of movies between actors:  3.0
# community  244  number of actors:  3
# community  244  average numbers of movies between actors:  3.0
# community  245  number of actors:  3
# community  245  average numbers of movies between actors:  4.666666666666667
# community  246  number of actors:  3
# community  246  average numbers of movies between actors:  3.0
# community  247  number of actors:  3
# community  247  average numbers of movies between actors:  3.5
# community  248  number of actors:  3
# community  248  average numbers of movies between actors:  3.0
# community  249  number of actors:  3
# community  249  average numbers of movies between actors:  3.0
# community  250  number of actors:  3
# community  250  average numbers of movies between actors:  3.3333333333333335
# community  251  number of actors:  3
# community  251  average numbers of movies between actors:  4.333333333333333
# community  252  number of actors:  2
# community  252  average numbers of movies between actors:  3.0
# community  253  number of actors:  2
# community  253  average numbers of movies between actors:  3.0
# community  254  number of actors:  2
# community  254  average numbers of movies between actors:  3.0
# community  255  number of actors:  2
# community  255  average numbers of movies between actors:  3.0
# community  256  number of actors:  2
# community  256  average numbers of movies between actors:  3.0
# community  257  number of actors:  2
# community  257  average numbers of movies between actors:  3.0
# community  258  number of actors:  2
# community  258  average numbers of movies between actors:  4.0
# community  259  number of actors:  2
# community  259  average numbers of movies between actors:  5.0
# community  260  number of actors:  2
# community  260  average numbers of movies between actors:  3.0
# community  261  number of actors:  2
# community  261  average numbers of movies between actors:  6.0
# community  262  number of actors:  2
# community  262  average numbers of movies between actors:  3.0
# community  263  number of actors:  2
# community  263  average numbers of movies between actors:  3.0
# community  264  number of actors:  2
# community  264  average numbers of movies between actors:  3.0
# community  265  number of actors:  2
# community  265  average numbers of movies between actors:  3.0
# community  266  number of actors:  2
# community  266  average numbers of movies between actors:  3.0
# community  267  number of actors:  2
# community  267  average numbers of movies between actors:  3.0
# community  268  number of actors:  2
# community  268  average numbers of movies between actors:  3.0
# community  269  number of actors:  2
# community  269  average numbers of movies between actors:  4.0
# community  270  number of actors:  2
# community  270  average numbers of movies between actors:  3.0
# community  271  number of actors:  2
# community  271  average numbers of movies between actors:  3.0
# community  272  number of actors:  2
# community  272  average numbers of movies between actors:  3.0
# community  273  number of actors:  2
# community  273  average numbers of movies between actors:  3.0
# community  274  number of actors:  2
# community  274  average numbers of movies between actors:  3.0
# community  275  number of actors:  2
# community  275  average numbers of movies between actors:  3.0
# community  276  number of actors:  2
# community  276  average numbers of movies between actors:  3.0
# community  277  number of actors:  2
# community  277  average numbers of movies between actors:  3.0
# community  278  number of actors:  2
# community  278  average numbers of movies between actors:  3.0
# community  279  number of actors:  2
# community  279  average numbers of movies between actors:  4.0
# community  280  number of actors:  2
# community  280  average numbers of movies between actors:  3.0
# community  281  number of actors:  2
# community  281  average numbers of movies between actors:  3.0
# community  282  number of actors:  2
# community  282  average numbers of movies between actors:  3.0
# community  283  number of actors:  2
# community  283  average numbers of movies between actors:  3.0
# community  284  number of actors:  2
# community  284  average numbers of movies between actors:  3.0
# community  285  number of actors:  2
# community  285  average numbers of movies between actors:  3.0
# community  286  number of actors:  2
# community  286  average numbers of movies between actors:  6.0
# community  287  number of actors:  2
# community  287  average numbers of movies between actors:  3.0
# community  288  number of actors:  2
# community  288  average numbers of movies between actors:  3.0
# community  289  number of actors:  2
# community  289  average numbers of movies between actors:  3.0
# community  290  number of actors:  2
# community  290  average numbers of movies between actors:  3.0
# community  291  number of actors:  2
# community  291  average numbers of movies between actors:  4.0
# community  292  number of actors:  2
# community  292  average numbers of movies between actors:  3.0
# community  293  number of actors:  2
# community  293  average numbers of movies between actors:  3.0
# community  294  number of actors:  2
# community  294  average numbers of movies between actors:  3.0
# community  295  number of actors:  2
# community  295  average numbers of movies between actors:  4.0
# community  296  number of actors:  2
# community  296  average numbers of movies between actors:  3.0
# community  297  number of actors:  2
# community  297  average numbers of movies between actors:  3.0
# community  298  number of actors:  2
# community  298  average numbers of movies between actors:  3.0
# community  299  number of actors:  2
# community  299  average numbers of movies between actors:  3.0
# community  300  number of actors:  2
# community  300  average numbers of movies between actors:  3.0
# community  301  number of actors:  2
# community  301  average numbers of movies between actors:  3.0
# community  302  number of actors:  2
# community  302  average numbers of movies between actors:  3.0
# community  303  number of actors:  2
# community  303  average numbers of movies between actors:  9.0
# community  304  number of actors:  2
# community  304  average numbers of movies between actors:  3.0
# community  305  number of actors:  2
# community  305  average numbers of movies between actors:  3.0
# community  306  number of actors:  2
# community  306  average numbers of movies between actors:  3.0
# community  307  number of actors:  2
# community  307  average numbers of movies between actors:  3.0
# community  308  number of actors:  2
# community  308  average numbers of movies between actors:  3.0
# community  309  number of actors:  2
# community  309  average numbers of movies between actors:  3.0
# community  310  number of actors:  2
# community  310  average numbers of movies between actors:  3.0
# community  311  number of actors:  2
# community  311  average numbers of movies between actors:  3.0
# community  312  number of actors:  2
# community  312  average numbers of movies between actors:  3.0
# community  313  number of actors:  2
# community  313  average numbers of movies between actors:  3.0
# community  314  number of actors:  2
# community  314  average numbers of movies between actors:  3.0
# community  315  number of actors:  2
# community  315  average numbers of movies between actors:  3.0
# community  316  number of actors:  2
# community  316  average numbers of movies between actors:  3.0
# community  317  number of actors:  2
# community  317  average numbers of movies between actors:  3.0
# community  318  number of actors:  2
# community  318  average numbers of movies between actors:  3.0
# community  319  number of actors:  2
# community  319  average numbers of movies between actors:  3.0
# community  320  number of actors:  2
# community  320  average numbers of movies between actors:  3.0
# community  321  number of actors:  2
# community  321  average numbers of movies between actors:  3.0
# community  322  number of actors:  2
# community  322  average numbers of movies between actors:  6.0
# community  323  number of actors:  2
# community  323  average numbers of movies between actors:  3.0
# community  324  number of actors:  2
# community  324  average numbers of movies between actors:  3.0
# community  325  number of actors:  2
# community  325  average numbers of movies between actors:  3.0
# community  326  number of actors:  2
# community  326  average numbers of movies between actors:  4.0
# community  327  number of actors:  2
# community  327  average numbers of movies between actors:  3.0
# community  328  number of actors:  2
# community  328  average numbers of movies between actors:  3.0
# community  329  number of actors:  2
# community  329  average numbers of movies between actors:  4.0
# community  330  number of actors:  2
# community  330  average numbers of movies between actors:  3.0
# community  331  number of actors:  2
# community  331  average numbers of movies between actors:  3.0
# community  332  number of actors:  2
# community  332  average numbers of movies between actors:  3.0
# community  333  number of actors:  2
# community  333  average numbers of movies between actors:  3.0
# community  334  number of actors:  2
# community  334  average numbers of movies between actors:  3.0
# community  335  number of actors:  2
# community  335  average numbers of movies between actors:  3.0
# community  336  number of actors:  2
# community  336  average numbers of movies between actors:  3.0
# community  337  number of actors:  2
# community  337  average numbers of movies between actors:  3.0
# community  338  number of actors:  2
# community  338  average numbers of movies between actors:  5.0
# community  339  number of actors:  2
# community  339  average numbers of movies between actors:  3.0
# community  340  number of actors:  2
# community  340  average numbers of movies between actors:  4.0
# community  341  number of actors:  2
# community  341  average numbers of movies between actors:  3.0
# community  342  number of actors:  2
# community  342  average numbers of movies between actors:  3.0
# community  343  number of actors:  2
# community  343  average numbers of movies between actors:  3.0
# community  344  number of actors:  2
# community  344  average numbers of movies between actors:  3.0
# community  345  number of actors:  2
# community  345  average numbers of movies between actors:  3.0
# community  346  number of actors:  2
# community  346  average numbers of movies between actors:  3.0
# community  347  number of actors:  2
# community  347  average numbers of movies between actors:  3.0
# community  348  number of actors:  2
# community  348  average numbers of movies between actors:  4.0
# community  349  number of actors:  2
# community  349  average numbers of movies between actors:  3.0
# community  350  number of actors:  2
# community  350  average numbers of movies between actors:  3.0
# community  351  number of actors:  2
# community  351  average numbers of movies between actors:  3.0
# community  352  number of actors:  2
# community  352  average numbers of movies between actors:  3.0
# community  353  number of actors:  2
# community  353  average numbers of movies between actors:  3.0
# community  354  number of actors:  2
# community  354  average numbers of movies between actors:  4.0
# community  355  number of actors:  2
# community  355  average numbers of movies between actors:  6.0
# community  356  number of actors:  2
# community  356  average numbers of movies between actors:  3.0
# community  357  number of actors:  2
# community  357  average numbers of movies between actors:  3.0
# community  358  number of actors:  2
# community  358  average numbers of movies between actors:  3.0
# community  359  number of actors:  2
# community  359  average numbers of movies between actors:  3.0
# community  360  number of actors:  2
# community  360  average numbers of movies between actors:  3.0
# community  361  number of actors:  2
# community  361  average numbers of movies between actors:  3.0
# community  362  number of actors:  2
# community  362  average numbers of movies between actors:  8.0
# community  363  number of actors:  2
# community  363  average numbers of movies between actors:  5.0
# community  364  number of actors:  2
# community  364  average numbers of movies between actors:  3.0
# community  365  number of actors:  2
# community  365  average numbers of movies between actors:  3.0
# community  366  number of actors:  2
# community  366  average numbers of movies between actors:  14.0
# community  367  number of actors:  2
# community  367  average numbers of movies between actors:  3.0
# community  368  number of actors:  2
# community  368  average numbers of movies between actors:  3.0
# community  369  number of actors:  2
# community  369  average numbers of movies between actors:  3.0
# community  370  number of actors:  2
# community  370  average numbers of movies between actors:  3.0
# community  371  number of actors:  2
# community  371  average numbers of movies between actors:  3.0
# community  372  number of actors:  2
# community  372  average numbers of movies between actors:  3.0
# community  373  number of actors:  2
# community  373  average numbers of movies between actors:  3.0
# community  374  number of actors:  2
# community  374  average numbers of movies between actors:  4.0
# community  375  number of actors:  2
# community  375  average numbers of movies between actors:  3.0
# community  376  number of actors:  2
# community  376  average numbers of movies between actors:  3.0
# community  377  number of actors:  2
# community  377  average numbers of movies between actors:  3.0
# community  378  number of actors:  2
# community  378  average numbers of movies between actors:  3.0
# community  379  number of actors:  2
# community  379  average numbers of movies between actors:  3.0
# community  380  number of actors:  2
# community  380  average numbers of movies between actors:  4.0
# community  381  number of actors:  2
# community  381  average numbers of movies between actors:  3.0
# community  382  number of actors:  2
# community  382  average numbers of movies between actors:  3.0
# community  383  number of actors:  2
# community  383  average numbers of movies between actors:  3.0
# community  384  number of actors:  2
# community  384  average numbers of movies between actors:  3.0
# community  385  number of actors:  2
# community  385  average numbers of movies between actors:  3.0
# community  386  number of actors:  2
# community  386  average numbers of movies between actors:  3.0
# community  387  number of actors:  2
# community  387  average numbers of movies between actors:  3.0
# community  388  number of actors:  2
# community  388  average numbers of movies between actors:  3.0
# community  389  number of actors:  2
# community  389  average numbers of movies between actors:  4.0
# community  390  number of actors:  2
# community  390  average numbers of movies between actors:  3.0
# community  391  number of actors:  2
# community  391  average numbers of movies between actors:  3.0
# community  392  number of actors:  2
# community  392  average numbers of movies between actors:  4.0
# community  393  number of actors:  2
# community  393  average numbers of movies between actors:  3.0
# community  394  number of actors:  2
# community  394  average numbers of movies between actors:  3.0
# community  395  number of actors:  2
# community  395  average numbers of movies between actors:  3.0
# community  396  number of actors:  2
# community  396  average numbers of movies between actors:  3.0
# community  397  number of actors:  2
# community  397  average numbers of movies between actors:  4.0
# community  398  number of actors:  2
# community  398  average numbers of movies between actors:  3.0
# community  399  number of actors:  2
# community  399  average numbers of movies between actors:  4.0
# community  400  number of actors:  2
# community  400  average numbers of movies between actors:  3.0
# community  401  number of actors:  2
# community  401  average numbers of movies between actors:  3.0
# community  402  number of actors:  2
# community  402  average numbers of movies between actors:  3.0
# community  403  number of actors:  2
# community  403  average numbers of movies between actors:  3.0
# community  404  number of actors:  2
# community  404  average numbers of movies between actors:  3.0
# community  405  number of actors:  2
# community  405  average numbers of movies between actors:  3.0
# community  406  number of actors:  2
# community  406  average numbers of movies between actors:  3.0
# community  407  number of actors:  2
# community  407  average numbers of movies between actors:  3.0
# community  408  number of actors:  2
# community  408  average numbers of movies between actors:  3.0
# community  409  number of actors:  2
# community  409  average numbers of movies between actors:  3.0
# community  410  number of actors:  2
# community  410  average numbers of movies between actors:  3.0
# community  411  number of actors:  2
# community  411  average numbers of movies between actors:  3.0
# community  412  number of actors:  2
# community  412  average numbers of movies between actors:  3.0
# community  413  number of actors:  2
# community  413  average numbers of movies between actors:  3.0
# community  414  number of actors:  2
# community  414  average numbers of movies between actors:  3.0
# community  415  number of actors:  2
# community  415  average numbers of movies between actors:  3.0
# community  416  number of actors:  2
# community  416  average numbers of movies between actors:  3.0
# community  417  number of actors:  2
# community  417  average numbers of movies between actors:  3.0
# community  418  number of actors:  2
# community  418  average numbers of movies between actors:  3.0
# community  419  number of actors:  2
# community  419  average numbers of movies between actors:  3.0
# community  420  number of actors:  2
# community  420  average numbers of movies between actors:  3.0
# community  421  number of actors:  2
# community  421  average numbers of movies between actors:  3.0
# community  422  number of actors:  2
# community  422  average numbers of movies between actors:  3.0
# community  423  number of actors:  2
# community  423  average numbers of movies between actors:  3.0
# community  424  number of actors:  2
# community  424  average numbers of movies between actors:  3.0
# community  425  number of actors:  2
# community  425  average numbers of movies between actors:  3.0
# community  426  number of actors:  2
# community  426  average numbers of movies between actors:  3.0
# community  427  number of actors:  2
# community  427  average numbers of movies between actors:  3.0
# community  428  number of actors:  2
# community  428  average numbers of movies between actors:  3.0
# community  429  number of actors:  2
# community  429  average numbers of movies between actors:  3.0
# community  430  number of actors:  2
# community  430  average numbers of movies between actors:  3.0
# community  431  number of actors:  2
# community  431  average numbers of movies between actors:  3.0
# community  432  number of actors:  2
# community  432  average numbers of movies between actors:  3.0
# community  433  number of actors:  2
# community  433  average numbers of movies between actors:  3.0
# community  434  number of actors:  2
# community  434  average numbers of movies between actors:  4.0
# community  435  number of actors:  2
# community  435  average numbers of movies between actors:  3.0
# community  436  number of actors:  2
# community  436  average numbers of movies between actors:  3.0
# community  437  number of actors:  2
# community  437  average numbers of movies between actors:  3.0
# community  438  number of actors:  2
# community  438  average numbers of movies between actors:  3.0
# community  439  number of actors:  2
# community  439  average numbers of movies between actors:  8.0
# community  440  number of actors:  2
# community  440  average numbers of movies between actors:  3.0
# community  441  number of actors:  2
# community  441  average numbers of movies between actors:  3.0
# community  442  number of actors:  2
# community  442  average numbers of movies between actors:  3.0
# community  443  number of actors:  2
# community  443  average numbers of movies between actors:  3.0
# community  444  number of actors:  2
# community  444  average numbers of movies between actors:  6.0
# community  445  number of actors:  2
# community  445  average numbers of movies between actors:  3.0
# community  446  number of actors:  2
# community  446  average numbers of movies between actors:  3.0
# community  447  number of actors:  2
# community  447  average numbers of movies between actors:  3.0
# community  448  number of actors:  2
# community  448  average numbers of movies between actors:  3.0
# community  449  number of actors:  2
# community  449  average numbers of movies between actors:  3.0
# community  450  number of actors:  2
# community  450  average numbers of movies between actors:  4.0
# community  451  number of actors:  2
# community  451  average numbers of movies between actors:  5.0
# community  452  number of actors:  2
# community  452  average numbers of movies between actors:  3.0
# community  453  number of actors:  2
# community  453  average numbers of movies between actors:  5.0
# community  454  number of actors:  2
# community  454  average numbers of movies between actors:  4.0
# community  455  number of actors:  2
# community  455  average numbers of movies between actors:  3.0
# community  456  number of actors:  2
# community  456  average numbers of movies between actors:  4.0
# community  457  number of actors:  2
# community  457  average numbers of movies between actors:  3.0
# community  458  number of actors:  2
# community  458  average numbers of movies between actors:  3.0
# community  459  number of actors:  2
# community  459  average numbers of movies between actors:  3.0
# community  460  number of actors:  2
# community  460  average numbers of movies between actors:  3.0
# community  461  number of actors:  2
# community  461  average numbers of movies between actors:  3.0
# community  462  number of actors:  2
# community  462  average numbers of movies between actors:  3.0
# community  463  number of actors:  2
# community  463  average numbers of movies between actors:  3.0
# community  464  number of actors:  2
# community  464  average numbers of movies between actors:  3.0
# community  465  number of actors:  2
# community  465  average numbers of movies between actors:  3.0
# community  466  number of actors:  2
# community  466  average numbers of movies between actors:  3.0
# community  467  number of actors:  2
# ...
# community  481  number of actors:  2
# community  481  average numbers of movies between actors:  3.0
# community  482  number of actors:  2
# community  482  average numbers of movies between actors:  3.0
# community  483  number of actors:  2
# community  483  average numbers of movies between actors:  5.0
# community  484  number of actors:  2
# community  484  average numbers of movies between actors:  3.0
# community  485  number of actors:  2
# community  485  average numbers of movies between actors:  3.0
# community  486  number of actors:  2
# community  486  average numbers of movies between actors:  3.0
# community  487  number of actors:  2
# community  487  average numbers of movies between actors:  3.0
# community  488  number of actors:  2
# community  488  average numbers of movies between actors:  3.0
# community  489  number of actors:  2
# community  489  average numbers of movies between actors:  3.0
# community  490  number of actors:  2
# community  490  average numbers of movies between actors:  3.0
# community  491  number of actors:  2
# community  491  average numbers of movies between actors:  3.0
# community  492  number of actors:  2
# community  492  average numbers of movies between actors:  3.0
# community  493  number of actors:  2
# community  493  average numbers of movies between actors:  3.0
# community  494  number of actors:  2
# community  494  average numbers of movies between actors:  4.0
# community  495  number of actors:  2
# community  495  average numbers of movies between actors:  3.0
# community  496  number of actors:  2
# community  496  average numbers of movies between actors:  3.0
# community  497  number of actors:  2
# community  497  average numbers of movies between actors:  3.0
# community  498  number of actors:  2
# community  498  average numbers of movies between actors:  3.0
# community  499  number of actors:  2
# community  499  average numbers of movies between actors:  3.0
# community  500  number of actors:  2
# community  500  average numbers of movies between actors:  3.0
# community  501  number of actors:  2
# community  501  average numbers of movies between actors:  3.0
# community  502  number of actors:  2
# community  502  average numbers of movies between actors:  3.0
# community  503  number of actors:  2
# community  503  average numbers of movies between actors:  3.0
# community  504  number of actors:  2
# community  504  average numbers of movies between actors:  3.0
# community  505  number of actors:  2
# community  505  average numbers of movies between actors:  3.0
# community  506  number of actors:  2
# community  506  average numbers of movies between actors:  3.0
# community  507  number of actors:  2
# community  507  average numbers of movies between actors:  3.0
# community  508  number of actors:  2
# community  508  average numbers of movies between actors:  3.0
# community  509  number of actors:  2
# community  509  average numbers of movies between actors:  3.0
# community  510  number of actors:  2
# community  510  average numbers of movies between actors:  3.0
# community  511  number of actors:  2
# community  511  average numbers of movies between actors:  3.0
# community  512  number of actors:  2
# community  512  average numbers of movies between actors:  3.0
# community  513  number of actors:  2
# community  513  average numbers of movies between actors:  3.0
# community  514  number of actors:  2
# community  514  average numbers of movies between actors:  3.0
# community  515  number of actors:  2
# community  515  average numbers of movies between actors:  3.0
# community  516  number of actors:  2
# community  516  average numbers of movies between actors:  3.0
# community  517  number of actors:  2
# community  517  average numbers of movies between actors:  3.0
# community  518  number of actors:  2
# community  518  average numbers of movies between actors:  3.0
# community  519  number of actors:  2
# community  519  average numbers of movies between actors:  3.0
# community  520  number of actors:  2
# community  520  average numbers of movies between actors:  3.0
# community  521  number of actors:  2
# community  521  average numbers of movies between actors:  3.0
# community  522  number of actors:  2
# community  522  average numbers of movies between actors:  3.0
# community  523  number of actors:  2
# community  523  average numbers of movies between actors:  3.0
# community  524  number of actors:  2
# community  524  average numbers of movies between actors:  4.0
# community  525  number of actors:  2
# community  525  average numbers of movies between actors:  3.0
# community  526  number of actors:  2
# community  526  average numbers of movies between actors:  3.0
# community  527  number of actors:  2
# community  527  average numbers of movies between actors:  4.0
# community  528  number of actors:  2
# community  528  average numbers of movies between actors:  3.0
# community  529  number of actors:  2
# community  529  average numbers of movies between actors:  3.0
# community  530  number of actors:  2
# community  530  average numbers of movies between actors:  3.0
# community  531  number of actors:  2
# community  531  average numbers of movies between actors:  3.0
# community  532  number of actors:  2
# community  532  average numbers of movies between actors:  3.0
# community  533  number of actors:  2
# community  533  average numbers of movies between actors:  3.0
# community  534  number of actors:  2
# community  534  average numbers of movies between actors:  3.0
# community  535  number of actors:  2
# community  535  average numbers of movies between actors:  3.0
# community  536  number of actors:  2
# community  536  average numbers of movies between actors:  3.0
# community  537  number of actors:  2
# community  537  average numbers of movies between actors:  3.0
# community  538  number of actors:  2
# community  538  average numbers of movies between actors:  3.0
# community  539  number of actors:  2
# community  539  average numbers of movies between actors:  3.0
# community  540  number of actors:  2
# community  540  average numbers of movies between actors:  3.0
# community  541  number of actors:  2
# community  541  average numbers of movies between actors:  3.0
# community  542  number of actors:  2
# community  542  average numbers of movies between actors:  3.0
# community  543  number of actors:  2
# community  543  average numbers of movies between actors:  4.0
# community  544  number of actors:  2
# community  544  average numbers of movies between actors:  3.0
# community  545  number of actors:  2
# community  545  average numbers of movies between actors:  3.0
# community  546  number of actors:  2
# community  546  average numbers of movies between actors:  3.0
# community  547  number of actors:  2
# community  547  average numbers of movies between actors:  3.0
# community  548  number of actors:  2
# community  548  average numbers of movies between actors:  4.0
# community  549  number of actors:  2
# community  549  average numbers of movies between actors:  4.0
# community  550  number of actors:  2
# community  550  average numbers of movies between actors:  3.0
# community  551  number of actors:  2
# community  551  average numbers of movies between actors:  3.0
# community  552  number of actors:  2
# community  552  average numbers of movies between actors:  3.0
# community  553  number of actors:  2
# community  553  average numbers of movies between actors:  5.0
# community  554  number of actors:  2
# community  554  average numbers of movies between actors:  3.0
# community  555  number of actors:  2
# community  555  average numbers of movies between actors:  3.0
# community  556  number of actors:  2
# community  556  average numbers of movies between actors:  3.0
# community  557  number of actors:  2
# community  557  average numbers of movies between actors:  3.0
# community  558  number of actors:  2
# community  558  average numbers of movies between actors:  3.0
# community  559  number of actors:  2
# community  559  average numbers of movies between actors:  3.0
# community  560  number of actors:  2
# community  560  average numbers of movies between actors:  3.0
# community  561  number of actors:  2
# community  561  average numbers of movies between actors:  3.0
# community  562  number of actors:  2
# community  562  average numbers of movies between actors:  3.0
# community  563  number of actors:  2
# community  563  average numbers of movies between actors:  3.0
# community  564  number of actors:  2
# community  564  average numbers of movies between actors:  3.0
# community  565  number of actors:  2
# community  565  average numbers of movies between actors:  3.0
# community  566  number of actors:  2
# community  566  average numbers of movies between actors:  3.0
# community  567  number of actors:  2
# community  567  average numbers of movies between actors:  3.0
# community  568  number of actors:  2
# community  568  average numbers of movies between actors:  3.0
# community  569  number of actors:  2
# community  569  average numbers of movies between actors:  4.0
# community  570  number of actors:  2
# community  570  average numbers of movies between actors:  5.0
# community  571  number of actors:  2
# community  571  average numbers of movies between actors:  3.0
# community  572  number of actors:  2
# community  572  average numbers of movies between actors:  3.0
# community  573  number of actors:  2
# community  573  average numbers of movies between actors:  3.0
# community  574  number of actors:  2
# community  574  average numbers of movies between actors:  3.0
# community  575  number of actors:  2
# community  575  average numbers of movies between actors:  4.0
# community  576  number of actors:  2
# community  576  average numbers of movies between actors:  3.0
# community  577  number of actors:  2
# community  577  average numbers of movies between actors:  3.0
# community  578  number of actors:  2
# community  578  average numbers of movies between actors:  3.0
# community  579  number of actors:  2
# community  579  average numbers of movies between actors:  4.0
# community  580  number of actors:  2
# community  580  average numbers of movies between actors:  3.0
# community  581  number of actors:  2
# community  581  average numbers of movies between actors:  3.0
# community  582  number of actors:  2
# community  582  average numbers of movies between actors:  4.0
# community  583  number of actors:  2
# community  583  average numbers of movies between actors:  4.0
# community  584  number of actors:  2
# community  584  average numbers of movies between actors:  3.0
# community  585  number of actors:  2
# community  585  average numbers of movies between actors:  3.0
# community  586  number of actors:  2
# community  586  average numbers of movies between actors:  3.0
# community  587  number of actors:  2
# community  587  average numbers of movies between actors:  3.0
# community  588  number of actors:  2
# community  588  average numbers of movies between actors:  3.0
# community  589  number of actors:  2
# community  589  average numbers of movies between actors:  3.0
# community  590  number of actors:  2
# community  590  average numbers of movies between actors:  3.0
# community  591  number of actors:  2
# community  591  average numbers of movies between actors:  3.0
# community  592  number of actors:  2
# community  592  average numbers of movies between actors:  3.0
# community  593  number of actors:  2
# community  593  average numbers of movies between actors:  3.0
# community  594  number of actors:  2
# community  594  average numbers of movies between actors:  3.0
# community  595  number of actors:  2
# community  595  average numbers of movies between actors:  3.0
# community  596  number of actors:  2
# community  596  average numbers of movies between actors:  4.0
# community  597  number of actors:  2
# community  597  average numbers of movies between actors:  3.0
# community  598  number of actors:  2
# community  598  average numbers of movies between actors:  3.0
# community  599  number of actors:  2
# community  599  average numbers of movies between actors:  3.0
# community  600  number of actors:  2
# community  600  average numbers of movies between actors:  3.0
# community  601  number of actors:  2
# community  601  average numbers of movies between actors:  3.0
# community  602  number of actors:  2
# community  602  average numbers of movies between actors:  3.0
# community  603  number of actors:  2
# community  603  average numbers of movies between actors:  3.0
# community  604  number of actors:  2
# community  604  average numbers of movies between actors:  3.0
# community  605  number of actors:  2
# community  605  average numbers of movies between actors:  3.0
# community  606  number of actors:  2
# community  606  average numbers of movies between actors:  3.0
# community  607  number of actors:  2
# community  607  average numbers of movies between actors:  3.0
# community  608  number of actors:  2
# community  608  average numbers of movies between actors:  3.0
# community  609  number of actors:  2
# community  609  average numbers of movies between actors:  3.0
# community  610  number of actors:  2
# community  610  average numbers of movies between actors:  3.0
# community  611  number of actors:  2
# community  611  average numbers of movies between actors:  3.0
# community  612  number of actors:  2
# community  612  average numbers of movies between actors:  3.0
# community  613  number of actors:  2
# community  613  average numbers of movies between actors:  3.0
# community  614  number of actors:  2
# community  614  average numbers of movies between actors:  3.0
# community  615  number of actors:  2
# community  615  average numbers of movies between actors:  3.0
# community  616  number of actors:  2
# community  616  average numbers of movies between actors:  3.0
# community  617  number of actors:  2
# community  617  average numbers of movies between actors:  3.0
# community  618  number of actors:  2
# community  618  average numbers of movies between actors:  3.0
# community  619  number of actors:  2
# community  619  average numbers of movies between actors:  3.0
# community  620  number of actors:  2
# community  620  average numbers of movies between actors:  3.0
# community  621  number of actors:  2
# community  621  average numbers of movies between actors:  3.0
# community  622  number of actors:  2
# community  622  average numbers of movies between actors:  3.0
# community  623  number of actors:  2
# community  623  average numbers of movies between actors:  3.0
# community  624  number of actors:  2
# community  624  average numbers of movies between actors:  5.0
# community  625  number of actors:  2
# community  625  average numbers of movies between actors:  3.0
# community  626  number of actors:  2
# community  626  average numbers of movies between actors:  3.0
# community  627  number of actors:  2
# community  627  average numbers of movies between actors:  3.0
# community  628  number of actors:  2
# community  628  average numbers of movies between actors:  5.0
# community  629  number of actors:  2
# community  629  average numbers of movies between actors:  3.0
# community  630  number of actors:  2
# community  630  average numbers of movies between actors:  3.0
# community  631  number of actors:  2
# community  631  average numbers of movies between actors:  3.0
# community  632  number of actors:  2
# community  632  average numbers of movies between actors:  3.0
# community  633  number of actors:  2
# community  633  average numbers of movies between actors:  3.0
# community  634  number of actors:  2
# community  634  average numbers of movies between actors:  3.0
# community  635  number of actors:  2
# community  635  average numbers of movies between actors:  3.0
# community  636  number of actors:  2
# community  636  average numbers of movies between actors:  3.0
# community  637  number of actors:  2
# community  637  average numbers of movies between actors:  3.0
# community  638  number of actors:  2
# community  638  average numbers of movies between actors:  3.0
# community  639  number of actors:  2
# community  639  average numbers of movies between actors:  4.0
# community  640  number of actors:  2
# community  640  average numbers of movies between actors:  3.0

# %% [markdown]
# ## 3.3 Vizualising the network

# %% [markdown]
# Let's start the funny part with a basic visualization.

# %%
# vizualise the obtained partitions (top 20 communities)
viz.plot_network_clusters(G, coms, node_size=20, figsize=(20, 20), plot_labels=False, top_k=20)

# %%
viz.plot_community_graph(G, coms, node_size=20, figsize=(20, 20), plot_labels=False, top_k=20)

# %% [markdown]
# ## 3.4 Analysing subnetworks

# %% [markdown]
# If we aim to see tendancies between those subgroup, we'll need to add features to nodes.

# %%
for n in G.nodes:
    G.nodes[n]['actor_gender'] = character_metadata[character_metadata.Actor_name == n]['actor_gender'].iloc[0]
    G.nodes[n]['Actor_ethnicity'] = character_metadata[character_metadata.Actor_name == n]['Actor_ethnicity'].iloc[0]

# %% [markdown]
# We can now compute the assortativity  for certains properties. It measures the similarity of connections in the graph with respect to the given attribute.

# %%
print("gender homophily: ", nx.attribute_assortativity_coefficient(G, 'actor_gender'))
print("ethnicity homophily: ", nx.attribute_assortativity_coefficient(G, 'Actor_ethnicity'))
# Out:
# gender homophily:  -0.014499575415650832
# ethnicity homophily:  0.19201049489434607

# %%
# store the top 20 communities in dataframes
# each row in the dataframe is an actor in the community, the connectivity column represents the total weight of the edges that the actor is connected to
# i.e the total number of movies the actor acted in with the other actors in the community
top_20_communities = []
for i, subgraph in enumerate(subgraphs[:20]):
    top_20_communities.append(pd.DataFrame(subgraph.degree(weight='Number_of_common_movies'), columns=['Actor_name', 'connectivity']).sort_values('connectivity', ascending=False))

# %%
# for each community add columns for actors ethnicity, gender and date of birth from the character_metadata dataframe
for i, community in enumerate(top_20_communities):
    top_20_communities[i] = community.merge(character_metadata[['Actor_name','actor_gender', 'Actor_date_of_birth', 'Actor_ethnicity']], on='Actor_name', how='inner').drop_duplicates(subset=['Actor_name']).reset_index(drop=True)

# %%
G = nx.connected_watts_strogatz_graph(30,5,.2)
nodes = G.nodes()
edges=list(G.edges(data=True))
